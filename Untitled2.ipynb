# %% [markdown]
# <a href="https://colab.research.google.com/github/Azmann010/32647-Azman/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/ibm-ice/Data-Exchange/refs/heads/main/FuelConsumptionCo2.csv'
df = pd.read_csv(url)

# %%
# summarize the data
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %%
viz = cdf[['CYLINDERS','ENGINESIZE','CO2EMISSIONS','FUELCONSUMPTION_COMB']]
viz.hist()
plt.tight_layout() # to prevent over lapping of graphs
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = cdf[['ENGINESIZE']]
y = cdf[['CO2EMISSIONS']]
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.33, random_state=42)

#import ml model
from sklearn.linear_model import LinearRegression
linmodel = LinearRegression()

#fit model
linmodel.fit(X_train, y_train)

#predictins
y_pred = linmodel.predict(X_test)

#accuray
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7648412489948487

# %%
plt.scatter(x_train.ENGINESIZE, y_train, color='blue')
plt.plot(x_train, linmodel.coef_[0][0]*x_train + linmodel.intercept_[0], '-r') # Corrected line
plt.xlabel("ENGINE SIZE")
plt.ylabel("EMISSIONS")
# Out:
# Text(0, 0.5, 'EMISSIONS')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
import seaborn as sns

# Assuming 'FuelConsumptionCo2.csv' is in the same directory as your notebook
url = 'https://raw.githubusercontent.com/ibm-ice/Data-Exchange/refs/heads/main/FuelConsumptionCo2.csv'
df = pd.read_csv(url)  # Defining df here

# Rest of your code...

plt.figure(figsize=(12,10))  # Set figure size
   sns.heatmap(cor, annot=True)  # Create heatmap with annotations
   plt.show()  # Display the plot
# Out:
#   File "<ipython-input-10-e29c4e3928aa>", line 15
#     sns.heatmap(cor, annot=True)  # Create heatmap with annotations
#     ^
# IndentationError: unexpected indent
